# %%
# http://economics.fundamentalfinance.com/game-theory/nash-equilibrium.php

# %%
from MWU import Sto_Game
# import pandas as pd

# %% [markdown]
# ## Multiplicative Weight Update Algorithm
#
# $$\huge w^{t+1}(a) = w^t(a)(1-\epsilon)^{c^t(a)}$$

# %% [markdown]
# # $\epsilon=0.5$

# %%
action_list = [['Head', 'Tail'],['Head', 'Tail']]
cost_list = [[[-1,1],[1,-1]],[[1,-1],[-1,1]]]
Matching = Sto_Game(action_list, cost_list)

Matching.MWU(10000,0.005)
# Matching.plot()
# Out:
# Training for 10000 steps is done

# %%
Matching.plot_scatter()

# %% [markdown]
# # $\epsilon=\frac{1}{t^{2/3}}$

# %%
action_list = [['Head', 'Tail'],['Head', 'Tail']]
cost_list = [[[-1,1],[1,-1]],[[1,-1],[-1,1]]]
Matching = Sto_Game(action_list, cost_list)
history = Matching.MWU(100000, new_ep=lambda ep, t:0.3/t**(2/3))
# Matching.plot()
Matching.plot_scatter()
# Out:
# Training for 100000 steps is done

# %%
action_list = [['Head', 'Tail'],['Head', 'Tail']]
cost_list = [[[-1,1],[1,-1]],[[1,-1],[-1,1]]]
Matching = Sto_Game(action_list, cost_list)
history = Matching.MWU(100000, new_ep=lambda ep, t:0.2/t**(2/3))
# Matching.plot()
Matching.plot_scatter()
# Out:
# Training for 100000 steps is done

# %%
action_list = [['Head', 'Tail'],['Head', 'Tail']]
cost_list = [[[-1,1],[1,-1]],[[1,-1],[-1,1]]]
Matching = Sto_Game(action_list, cost_list)
history = Matching.MWU(100000, new_ep=lambda ep, t:0.1/t**(2/3))
# Matching.plot()
Matching.plot_scatter()
# Out:
# Training for 100000 steps is done

# %%
action_list = [['Head', 'Tail'],['Head', 'Tail']]
cost_list = [[[-1,1],[1,-1]],[[1,-1],[-1,1]]]
Matching = Sto_Game(action_list, cost_list)
history = Matching.MWU(100000, new_ep=lambda ep, t:0.05/t**(2/3))
# Matching.plot()
Matching.plot_scatter()
# Out:
# Training for 100000 steps is done
